# %% [markdown]
# ### CASE STUDY:  future sales prediction with machine learning using Python.
# The dataset given here contains the data about the sales of the product. The dataset is about the advertising cost incurred by the business on various advertising platforms.
#
#
# Below is the description of all the columns in the dataset:
#
# TV: Advertising cost spent in dollars for advertising on TV;
# Radio: Advertising cost spent in dollars for advertising on Radio;
# Newspaper: Advertising cost spent in dollars for advertising on Newspaper;
# Sales: Number of units sold;
#
# So, in the given
# dataset, the sales of the product depend on the advertisement cost of the product.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')


import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

data = pd.read_csv (r"C:\Users\am100\OneDrive\Desktop\study_maps\advertising_data.csv")
print(data.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# ### Importing libreries and pulling Data:

# %% [markdown]
# ### Data Cleaning

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# null values  are not present

# %%
# visualizing the relationship between the amount spent on advertising on TV and units sold:


fig = px.scatter(data_frame = data, x="Sales",
                    y="TV",  size="TV",trendline="ols")
fig.show()
# Out:
# <div>                            <div id="ae048737-8304-4a16-bcc1-21bb3e98cacf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae048737-8304-4a16-bcc1-21bb3e98cacf")) {                    Plotly.newPlot(                        "ae048737-8304-4a16-bcc1-21bb3e98cacf",                        [{"hovertemplate":"Sales=%{x}<br>TV=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[230.1,44.5,17.2,151.5,180.8,8.7,57.5,120.2,8.6,199.8,66.1,214.7,23.8,97.5,204.1,195.4,67.8,281.4,69.2,147.3,218.4,237.4,13.2,228.3,62.3,262.9,142.9,240.1,248.8,70.6,292.9,112.9,97.2,265.6,95.7,290.7,266.9,74.7,43.1,228.0,202.5,177.0,293.6,206.9,25.1,175.1,89.7,239.9,227.2,66.9,199.8,100.4,216.4,182.6,262.7,198.9,7.3,136.2,210.8,210.7,53.5,261.3,2
# ...

# %%
# visualizing the relationship between the amount spent on advertising on Newspapers and units sold:


fig = px.scatter(data_frame = data, x="Sales",
                    y="Newspaper",  size="Newspaper",trendline="ols")
fig.show()
# Out:
# <div>                            <div id="53219d25-9a7c-43e2-883b-8422d54eb21d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53219d25-9a7c-43e2-883b-8422d54eb21d")) {                    Plotly.newPlot(                        "53219d25-9a7c-43e2-883b-8422d54eb21d",                        [{"hovertemplate":"Sales=%{x}<br>Newspaper=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[69.2,45.1,69.3,58.5,58.4,75.0,23.5,11.6,1.0,21.2,24.2,4.0,65.9,7.2,46.0,52.9,114.0,55.8,18.3,19.1,53.4,23.5,49.6,26.2,18.3,19.5,12.6,22.9,22.9,40.8,43.2,38.6,30.0,0.3,7.4,8.5,5.0,45.7,35.1,32.0,31.6,38.7,1.8,26.4,43.3,31.5,35.7,18.5,49.9,36.8,34.6,3.6,39.6,58.7,15.9,60.0,41.4,16.6,37.7,9.3,21.4,54.7,27.3,8.4,28.9,0.9,2.2,10.2,11.0,27.2,38.
# ...

# %%
# visualizing the relationship between the amount spent on advertising on Newspapers and units sold:


fig = px.scatter(data_frame = data, x="Sales",
                    y="Radio",  size="Radio",trendline="ols")
fig.show()
# Out:
# <div>                            <div id="d7531824-e212-4741-b083-91d5c6d9d65a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7531824-e212-4741-b083-91d5c6d9d65a")) {                    Plotly.newPlot(                        "d7531824-e212-4741-b083-91d5c6d9d65a",                        [{"hovertemplate":"Sales=%{x}<br>Radio=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[37.8,39.3,45.9,41.3,10.8,48.9,32.8,19.6,2.1,2.6,5.8,24.0,35.1,7.6,32.9,47.7,36.6,39.6,20.5,23.9,27.7,5.1,15.9,16.9,12.6,3.5,29.3,16.7,27.1,16.0,28.3,17.4,1.5,20.0,1.4,4.1,43.8,49.4,26.7,37.7,22.3,33.4,27.7,8.4,25.7,22.5,9.9,41.5,15.8,11.7,3.1,9.6,41.7,46.2,28.8,49.4,28.1,19.2,49.6,29.5,2.0,42.7,15.5,29.6,42.8,9.3,24.6,14.5,27.5,43.9,30.6,14.3,
# ...

# %% [markdown]
# ### Inference:
# out of all the various mediums of advert we can conclude from the above vizualization that T.V plays an important role to boast the sales.

# %%
#correlation of all the columns with the sales column:
Correlation = data.corr()
print(Correlation['Sales'].sort_values(ascending=False))
# Out:
# Sales        1.000000
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Name: Sales, dtype: float64

# %%
sns.heatmap(data=data)
plt.show()

# %%
#split the data into training and test sets
x = data.drop(["Sales"], axis = 1)
y = data["Sales"]
xtrain, xtest, ytrain, ytest = train_test_split(x, y, 
                                                test_size=0.2, 
                                                random_state=42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
print(model.score(xtest, ytest))
# Out:
# 0.9059011844150826

# %% [markdown]
# ### Predction Model :
# input values into the model according to the features we have used to train it and
# predict how many units of the product can be sold based on the amount spent on its advertising on various platforms:

# %%
features = [[data.TV, data.Radio, data.Newspaper]]
features = np.array([[400, 61.8, 20.2]])
print(model.predict(features))
# Out:
# [32.8438584]
